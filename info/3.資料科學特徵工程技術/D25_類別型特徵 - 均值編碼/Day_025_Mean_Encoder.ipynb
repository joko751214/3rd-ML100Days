# %% [markdown]
# # 範例 : (Kaggle)房價預測
# ***
# - 以下用房價預測資料, 觀察均值編碼的效果

# %% [markdown]
# # [教學目標]
# - 以下用房價預測資料, 觀察均值編碼的效果

# %% [markdown]
# # [範例重點]
# - 觀察標籤編碼與均值編碼, 在特徵數量 / 線性迴歸分數 / 線性迴歸時間上, 分別有什麼影響 (In[3], Out[3], In[4], Out[4])
# - 觀察標籤編碼與均值編碼, 在特徵數量 / 梯度提升樹分數 / 梯度提升樹時間上, 分別有什麼影響 (In[5], Out[5], In[6], Out[6])

# %%
# 做完特徵工程前的所有準備
import pandas as pd
import numpy as np
import copy, time
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder

data_path = 'C:/Users/infiark/Desktop/review/GitHub/data/Part02/'
df_train = pd.read_csv(data_path + 'house_train.csv.gz')
df_test = pd.read_csv(data_path + 'house_test.csv.gz')

train_Y = np.log1p(df_train['SalePrice'])
ids = df_test['Id']
df_train = df_train.drop(['Id', 'SalePrice'] , axis=1)
df_test = df_test.drop(['Id'] , axis=1)
df = pd.concat([df_train,df_test])
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 3         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 4         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0       2    2008        WD         Normal
# 1         NaN       0       5    2007        WD         Normal
# 2         NaN       0       9    2008        WD         Normal
# 3         NaN       0       2    2006        WD        Abnorml
# 4         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %%
#只取類別值 (object) 型欄位, 存於 object_features 中
object_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'object':
        object_features.append(feature)
print(f'{len(object_features)} Numeric Features : {object_features}\n')

# 只留類別型欄位
df = df[object_features]
df = df.fillna('None')
train_num = train_Y.shape[0]
df.head()
# Out:
# 43 Numeric Features : ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave  None      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
#   PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition
# 0          Y   None  None        None       WD        Normal
# 1          Y   None  None        None       WD        Normal
# 2          Y   None  None        None       WD        Normal
# 3          Y   None  None        None       WD       Abnorml
# 4          Y   None  None        None       WD        Normal
#
# [5 rows x 43 columns]

# %%
# 對照組 : 標籤編碼 + 線性迴歸
df_temp = pd.DataFrame()
for c in df.columns:
    df_temp[c] = LabelEncoder().fit_transform(df[c])
train_X = df_temp[:train_num]
estimator = LinearRegression()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, train_X, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
# shape : (1460, 43)
# score : 0.6615606866851301
# time : 0.029999732971191406 sec

# %%
# 均值編碼 + 線性迴歸
data = pd.concat([df[:train_num], train_Y], axis=1)
for c in df.columns:
    mean_df = data.groupby([c])['SalePrice'].mean().reset_index()
    mean_df.columns = [c, f'{c}_mean']
    data = pd.merge(data, mean_df, on=c, how='left')
    data = data.drop([c] , axis=1)
data = data.drop(['SalePrice'] , axis=1)
estimator = LinearRegression()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, data, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
# shape : (1460, 43)
# score : 0.7624230403716955
# time : 0.015000104904174805 sec

# %%
# 對照組 : 標籤編碼 + 梯度提升樹
df_temp = pd.DataFrame()
for c in df.columns:
    df_temp[c] = LabelEncoder().fit_transform(df[c])
train_X = df_temp[:train_num]
estimator = GradientBoostingRegressor()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, train_X, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
# shape : (1460, 43)
# score : 0.7783758280436521
# time : 0.5922949314117432 sec

# %%
# 均值編碼 + 梯度提升樹
data = pd.concat([df[:train_num], train_Y], axis=1)
print(data)
for c in df.columns:
    mean_df = data.groupby([c])['SalePrice'].mean().reset_index()
    mean_df.columns = [c, f'{c}_mean']
    data = pd.merge(data, mean_df, on=c, how='left')
    data = data.drop([c] , axis=1)
print(data)
data = data.drop(['SalePrice'] , axis=1)
estimator = GradientBoostingRegressor()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, data, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave  None      IR1         Lvl    AllPub       FR2       Gtl
# 5          RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 6          RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 7          RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 8          RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 9          RL   Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 10         RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 11         RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 12         RL   Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 13         RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 14         RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 15         RM   Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 16         RL   Pave  None      IR1         Lvl    AllPub   CulDSac       Gtl
# 17         RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 18         RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 19         RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 20         RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 21         RM   Pave  Grvl      Reg         Bnk    AllPub    Inside       Gtl
# 22         RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 23         RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 24         RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 25         RL   Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 26         RL   Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 27         RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 28         RL   Pave  None      IR1         Lvl    AllPub   CulDSac       Gtl
# 29         RM   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1430       RL   Pave  None      IR3         Lvl    AllPub    Inside       Gtl
# 1431       RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 1432       RL   Pave  Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 1433       RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 1434       RL   Pave  None      Reg         Low    AllPub    Inside       Mod
# 1435       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1436       RL   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 1437       RL   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 1438       RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1439       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1440       RL   Pave  None      IR1         Bnk    AllPub    Inside       Mod
# 1441       RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1442       FV   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1443       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1444       RL   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 1445       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1446       RL   Pave  None      IR1         Lvl    AllPub   CulDSac       Gtl
# 1447       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1448       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1449       RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1450       RL   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 1451       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1452       RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1453       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1454       FV   Pave  Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1455       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1  ... GarageFinish GarageQual GarageCond  \
# 0         CollgCr       Norm  ...          RFn         TA         TA
# 1         Veenker      Feedr  ...          RFn         TA         TA
# 2         CollgCr       Norm  ...          RFn         TA         TA
# 3         Crawfor       Norm  ...          Unf         TA         TA
# 4         NoRidge       Norm  ...          RFn         TA         TA
# 5         Mitchel       Norm  ...          Unf         TA         TA
# 6         Somerst       Norm  ...          RFn         TA         TA
# 7          NWAmes       PosN  ...          RFn         TA         TA
# 8         OldTown     Artery  ...          Unf         Fa         TA
# 9         BrkSide     Artery  ...          RFn         Gd         TA
# 10         Sawyer       Norm  ...          Unf         TA         TA
# 11        NridgHt       Norm  ...          Fin         TA         TA
# 12         Sawyer       Norm  ...          Unf         TA         TA
# 13        CollgCr       Norm  ...          RFn         TA         TA
# 14          NAmes       Norm  ...          RFn         TA         TA
# 15        BrkSide       Norm  ...          Unf         TA         TA
# 16          NAmes       Norm  ...          Fin         TA         TA
# 17         Sawyer       Norm  ...          Unf         TA         TA
# 18        SawyerW       RRAe  ...          Unf         TA         TA
# 19          NAmes       Norm  ...          Unf         TA         TA
# 20        NridgHt       Norm  ...          RFn         TA         TA
# 21         IDOTRR       Norm  ...          Unf         TA         TA
# 22        CollgCr       Norm  ...          RFn         TA         TA
# 23        MeadowV       Norm  ...          Unf         TA         TA
# 24         Sawyer       Norm  ...          Unf         TA         TA
# 25        NridgHt       Norm  ...          RFn         TA         TA
# 26          NAmes       Norm  ...          Unf         TA         TA
# 27        NridgHt       Norm  ...          RFn         TA         TA
# 28          NAmes       Norm  ...          RFn         TA         TA
# 29        BrkSide      Feedr  ...          Unf         Fa         TA
# ...           ...        ...  ...          ...        ...        ...
# 1430      Gilbert       RRAn  ...          Fin         TA         TA
# 1431      NPkVill       Norm  ...          RFn         TA         TA
# 1432      OldTown       Norm  ...          Unf         Fa         Fa
# 1433      Gilbert       Norm  ...          Fin         TA         TA
# 1434      Mitchel       Norm  ...          RFn         TA         TA
# 1435        NAmes       Norm  ...          RFn         TA         TA
# 1436        NAmes       Norm  ...          Unf         TA         TA
# 1437      NridgHt       Norm  ...          Fin         TA         TA
# 1438      OldTown     Artery  ...          Unf         TA         TA
# 1439       NWAmes       Norm  ...          RFn         TA         TA
# 1440      Crawfor       Norm  ...          Fin         TA         TA
# 1441      CollgCr       Norm  ...          RFn         TA         TA
# 1442      Somerst       Norm  ...          Fin         TA         TA
# 1443      BrkSide       Norm  ...          Unf         Fa         Po
# 1444      CollgCr       Norm  ...          RFn         TA         TA
# 1445       Sawyer       Norm  ...          Unf         TA         TA
# 1446      Mitchel       Norm  ...          Unf         TA         TA
# 1447      CollgCr       Norm  ...          RFn         TA         TA
# 1448      Edwards       Norm  ...          Unf         Fa         TA
# 1449      MeadowV       Norm  ...         None       None       None
# 1450        NAmes       Norm  ...         None       None       None
# 1451      Somerst       Norm  ...          Fin         TA         TA
# 1452      Edwards       Norm  ...          Fin         TA         TA
# 1453      Mitchel       Norm  ...         None       None       None
# 1454      Somerst       Norm  ...          RFn         TA         TA
# 1455      Gilbert       Norm  ...          RFn         TA         TA
# 1456       NWAmes       Norm  ...          Unf         TA         TA
# 1457      Crawfor       Norm  ...          RFn         TA         TA
# 1458        NAmes       Norm  ...          Unf         TA         TA
# 1459      Edwards       Norm  ...          Fin         TA         TA
#
#      PavedDrive PoolQC  Fence MiscFeature SaleType SaleCondition  SalePrice
# 0             Y   None   None        None       WD        Normal  12.247699
# 1             Y   None   None        None       WD        Normal  12.109016
# 2             Y   None   None        None       WD        Normal  12.317171
# 3             Y   None   None        None       WD       Abnorml  11.849405
# 4             Y   None   None        None       WD        Normal  12.429220
# 5             Y   None  MnPrv        Shed       WD        Normal  11.870607
# 6             Y   None   None        None       WD        Normal  12.634606
# 7             Y   None   None        Shed       WD        Normal  12.206078
# 8             Y   None   None        None       WD       Abnorml  11.774528
# 9             Y   None   None        None       WD        Normal  11.678448
# 10            Y   None   None        None       WD        Normal  11.771444
# 11            Y   None   None        None      New       Partial  12.751303
# 12            Y   None   None        None       WD        Normal  11.877576
# 13            Y   None   None        None      New       Partial  12.540761
# 14            Y   None   GdWo        None       WD        Normal  11.964007
# 15            Y   None  GdPrv        None       WD        Normal  11.790565
# 16            Y   None   None        Shed       WD        Normal  11.911708
# 17            Y   None   None        Shed       WD        Normal  11.407576
# 18            Y   None   None        None       WD        Normal  11.976666
# 19            Y   None  MnPrv        None      COD       Abnorml  11.842236
# 20            Y   None   None        None      New       Partial  12.692506
# 21            N   None  GdPrv        None       WD        Normal  11.845110
# 22            Y   None   None        None       WD        Normal  12.345839
# 23            Y   None   None        None       WD        Normal  11.774528
# 24            Y   None  MnPrv        None       WD        Normal  11.944714
# 25            Y   None   None        None       WD        Normal  12.454108
# 26            Y   None   None        None       WD        Normal  11.811555
# 27            Y   None   None        None       WD        Normal  12.631344
# 28            Y   None   None        None       WD        Normal  12.242891
# 29            Y   None   None        None       WD        Normal  11.134604
# ...         ...    ...    ...         ...      ...           ...        ...
# 1430          Y   None   None        None       WD        Normal  12.165985
# 1431          Y   None   None        None       WD        Normal  11.875838
# 1432          Y   None   None        None       WD        Normal  11.074436
# 1433          Y   None   None        None       WD        Normal  12.136192
# 1434          P   None   None        None       WD        Normal  11.982935
# 1435          Y   None  GdPrv        None      COD       Abnorml  12.066816
# 1436          Y   None   GdWo        None       WD        Normal  11.699413
# 1437          Y   None   None        None      New       Partial  12.885673
# 1438          Y   None  MnPrv        None       WD        Normal  11.916395
# 1439          Y   None   None        None       WD        Normal  12.190964
# 1440          Y   None   None        None       WD        Normal  12.160034
# 1441          Y   None   None        None       WD        Normal  11.913720
# 1442          Y   None   None        None       WD        Normal  12.644331
# 1443          P   None   None        None       WD        Normal  11.703554
# 1444          Y   None   None        None       WD        Normal  12.098493
# 1445          Y   None   None        None       WD        Normal  11.767575
# 1446          P   None   None        None       WD        Normal  11.969724
# 1447          Y   None   None        None       WD        Normal  12.388398
# 1448          Y   None   GdWo        None       WD        Normal  11.626263
# 1449          Y   None   None        None       WD       Abnorml  11.429555
# 1450          Y   None   None        None       WD        Normal  11.820418
# 1451          Y   None   None        None      New       Partial  12.567555
# 1452          Y   None   None        None       WD        Normal  11.884496
# 1453          Y   None   None        None       WD       Abnorml  11.344519
# 1454          Y   None   None        None       WD        Normal  12.128117
# 1455          Y   None   None        None       WD        Normal  12.072547
# 1456          Y   None  MnPrv        None       WD        Normal  12.254868
# 1457          Y   None  GdPrv        Shed       WD        Normal  12.493133
# 1458          Y   None   None        None       WD        Normal  11.864469
# 1459          Y   None   None        None       WD        Normal  11.901590
#
# [1460 rows x 44 columns]
#       SalePrice  MSZoning_mean  Street_mean  Alley_mean  LotShape_mean  \
# 0     12.247699      12.085891    12.025529   12.037682      11.936101
# 1     12.109016      12.085891    12.025529   12.037682      11.936101
# 2     12.317171      12.085891    12.025529   12.037682      12.163471
# 3     11.849405      12.085891    12.025529   12.037682      12.163471
# 4     12.429220      12.085891    12.025529   12.037682      12.163471
# 5     11.870607      12.085891    12.025529   12.037682      12.163471
# 6     12.634606      12.085891    12.025529   12.037682      11.936101
# 7     12.206078      12.085891    12.025529   12.037682      12.163471
# 8     11.774528      11.692901    12.025529   12.037682      11.936101
# 9     11.678448      12.085891    12.025529   12.037682      11.936101
# 10    11.771444      12.085891    12.025529   12.037682      11.936101
# 11    12.751303      12.085891    12.025529   12.037682      12.163471
# 12    11.877576      12.085891    12.025529   12.037682      12.318455
# 13    12.540761      12.085891    12.025529   12.037682      12.163471
# 14    11.964007      12.085891    12.025529   12.037682      12.163471
